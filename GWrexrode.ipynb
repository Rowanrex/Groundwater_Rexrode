# %%
# !conda install -c conda-forge netcdf4 -y

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\romin\\Gw research'

# %%
import xarray as xr
ds = xr.open_dataset(r"C:\Users\romin\OneDrive\Desktop\Groundwater\neusa_ep_days_stats_seasonal_ep_days95NEW_fall.nc", engine="netcdf4")
print(ds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 import xarray as xr
# ----> 2 ds = xr.open_dataset(r"C:\Users\romin\OneDrive\Desktop\Groundwater\neusa_ep_days_stats_seasonal_ep_days95NEW_fall.nc", engine="netcdf4")
#       3 print(ds)
#
# File ~\anaconda3\Lib\site-packages\xarray\backends\api.py:582, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     579 if from_array_kwargs is None:
#     580     from_array_kwargs = {}
# --> 582 backend = plugins.get_backend(engine)
#     584 decoders = _resolve_decoders_kwargs(
#     585     decode_cf,
#     586     open_backend_dataset_parameters=backend.open_dataset_parameters,
# ...

# %%
import os
os.path.exists(r"C:\Users\romin\OneDrive\Desktop\Groundwater\neusa_ep_days_stats_seasonal_ep_days95NEW_fall.nc")
# Out:
# True

# %%
os.listdir(r"C:\Users\romina\Desktop")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.listdir(r"C:\Users\Romina\Desktop")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\Romina\\Desktop'

# %%
import os
print(os.path.expanduser("~"))
# Out:
# C:\Users\romin

# %%
import os
os.listdir(r"C:\Users\romin\Desktop")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import os
# ----> 2 os.listdir(r"C:\Users\romin\Desktop")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\romin\\Desktop'

# %%
import os
os.listdir(r"C:\Users\romin")
# Out:
# ['#2.1.1 grid of squares.py',
#  '#2.1.1 row of squares.py',
#  '#2.1.1 square.py',
#  '#2.1.1 stair of squares.py',
#  '#2.1.py',
#  '.anaconda',
#  '.cache',
#  '.conda',
#  '.continuum',
#  '.dotnet',
#  '.eclipse',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.p2',
#  '.virtual_documents',
#  '.vscode',
#  'anaconda3',
#  'AppData',
#  'Apple',
#  'Application Data',
#  'beer bottle python code loops lab (1).py',
#  'chocolate.py',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'draw super spiral.py',
#  'drawNgon.py',
#  'eclipse',
#  'eclipse-workspace',
#  'Favorites',
#  'Gw research',
#  'hourglass.py',
#  'lab 2.py',
#  'lab2',
#  'lab2rowan.txt',
#  'Links',
#  'Local Settings',
#  'messy.py',
#  'multiplication table.py',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{19517814-f292-11ef-8469-c52f8c08fb92}.TxR.0.regtrans-ms',
# ...

# %%
import os
for root, dirs, files in os.walk(r"C:\Users\romin"):
    for file in files:
        if file.endswith(".nc"):
            print(os.path.join(root, file))
# Out:
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_001_antialias_clipped.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_001_antialias_normal.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_001_noaa_clipped.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_001_noaa_normal.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_002_antialias_clipped.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_002_antialias_normal.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_002_noaa_clipped.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_002_noaa_normal.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_003_antialias_clipped.nc
# C:\Users\romin\anaconda3\Lib\site-packages\datashader\tests\data\test_003_antialias_normal.nc
# ...

# %%
os.listdir(r"C:\Users\romin\OneDrive\Desktop")
# Out:
# ['1-8-2025.reg',
#  'Bluebird change .mapx',
#  'Bluebird Presence Layout.pagx',
#  'data',
#  'desktop.ini',
#  'DXVK 2.6.1-79299-2-6-1-1748788948.7z',
#  'Eclipse IDE for Java Developers - 2024-06.lnk',
#  'Fallout New Vegas.url',
#  'finalproject1',
#  'Firefox.exe',
#  'Flashpoint.lnk',
#  'French and Pickering GIS Project',
#  'Groundwater',
#  'Microsoft Edge.lnk',
#  'Palia.url',
#  'Pie chart layout.pagx',
#  'Presence of Starlings and no Bluebirds.mapx',
#  'Roblox Player.lnk',
#  'Roblox Studio.lnk',
#  'Rowan - Chrome.lnk',
#  'Since You Asked Chapter 1.docx',
#  'StarnoBB16.mapx',
#  'TeamViewer Meeting.lnk',
#  'Zoom Workplace.lnk']
